# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from matplotlib import style
from matplotlib import pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf

# %matplotlib inline

pd.set_option("display.max_columns", 6)
style.use("fivethirtyeight")

# %%
data = (pd.read_csv("fertrate_world.csv"))
data.fillna(0,inplace=True)

data.query("china").head()
# Out:
#       region  year  fertrate  ...  CountryCode  china  after_treatment
# 2310     156  1950     6.650  ...          CHN   True            False
# 2311     156  1951     6.525  ...          CHN   True            False
# 2312     156  1952     6.400  ...          CHN   True            False
# 2313     156  1953     6.275  ...          CHN   True            False
# 2314     156  1954     6.150  ...          CHN   True            False
#
# [5 rows x 21 columns]

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# region             0
# year               0
# fertrate           0
# InfMRateCME        0
# InfMRateUN         0
# U5MRateCME         0
# U5MRateUN          0
# LifeExpB           0
# MtoFbirth          0
# MtoF04             0
# Pop1564            0
# Pop1564Female      0
# GDPpc              0
# GDPpcGrowth        0
# Yschooling         0
# YschoolF1549       0
# GenrollPrim        0
# ChildBearing       0
# CountryCode        0
# china              0
# after_treatment    0
# dtype: int64

# %%
ax = plt.subplot(1, 1, 1)

(data
 .assign(china = np.where(data["china"], "China", "Other Countries"))
 .groupby(["year", "china"])
 ["fertrate"]
 .mean()
 .reset_index()
 .pivot("year", "china", "fertrate")
 .plot(ax=ax, figsize=(10,5)))

plt.vlines(x=1973, ymin=10, ymax=2, linestyle=":", lw=2, label="One Child Policy")
plt.ylabel("Fertility Rate")
plt.title("Fertility v. Time")
plt.legend();

# %%
features = ["fertrate", "LifeExpB", "MtoF04", "Yschooling", "ChildBearing", "GDPpc"]

inverted = (data.query("~after_treatment") # filter pre-intervention period
            .pivot(index='region', columns="year")[features] # make one column per year and one row per state
            .T) # flip the table to have one column per state

inverted.head()
# Out:
# region          4        8       12   ...     862     882   894
#          year                         ...
# fertrate 1950  7.45  5.91380  7.1720  ...  6.4585  7.6297  6.45
#          1951  7.45  5.97704  7.1932  ...  6.4585  7.6297  6.50
#          1952  7.45  6.04028  7.2144  ...  6.4585  7.6297  6.55
#          1953  7.45  6.10352  7.2356  ...  6.4585  7.6297  6.60
#          1954  7.45  6.16676  7.2568  ...  6.4585  7.6297  6.65
#
# [5 rows x 187 columns]

# %%
inverted.isnull().sum()
# Out:
# region
# 4      0
# 8      0
# 12     0
# 24     0
# 28     0
#       ..
# 858    0
# 860    0
# 862    0
# 882    0
# 894    0
# Length: 187, dtype: int64

# %%
inverted = inverted.dropna()

# %%
y = inverted[156].values # china
X = inverted.drop(columns=156).values

# %%
from sklearn.linear_model import LinearRegression
weights_lr = LinearRegression(fit_intercept=False).fit(X, y).coef_
weights_lr.round(3)
# Out:
# array([ 0.052, -0.428, -0.105, -0.086, -0.186,  0.011, -0.201, -0.081,
#        -0.144, -0.014,  0.02 , -0.135, -0.059,  0.084,  0.017,  0.   ,
#         0.139,  0.072, -0.005,  0.229,  0.092,  0.023, -0.038, -0.109,
#         0.19 ,  0.046, -0.095,  0.163,  0.015,  0.142,  0.12 , -0.055,
#        -0.021, -0.278,  0.104,  0.17 ,  0.116, -0.067, -0.044,  0.036,
#         0.213,  0.164,  0.339, -0.232, -0.07 , -0.006,  0.03 , -0.104,
#         0.048, -0.12 , -0.015, -0.109, -0.   , -0.001, -0.056, -0.115,
#        -0.102,  0.062,  0.075,  0.172, -0.003,  0.202,  0.144, -0.08 ,
#        -0.069, -0.075, -0.059,  0.007, -0.124,  0.051, -0.033, -0.072,
#         0.105,  0.022,  0.096,  0.024, -0.035,  0.226,  0.102,  0.   ,
#         0.112, -0.03 ,  0.056, -0.068,  0.171,  0.177, -0.123,  0.017,
#        -0.039,  0.042, -0.051,  0.049, -0.077, -0.095, -0.137,  0.015,
#         0.089,  0.1  ,  0.096, -0.006, -0.041, -0.012,  0.028,  0.061,
#         0.093, -0.045, -0.135,  0.008, -0.297, -0.049,  0.294, -0.084,
#        -0.025, -0.065,  0.077, -0.076,  0.197, -0.025,  0.292, -0.014,
#        -0.203,  0.029,  0.115,  0.019, -0.091, -0.069,  0.067,  0.174,
#        -0.125,  0.122,  0.253, -0.047, -0.006,  0.084,  0.286,  0.009,
#        -0.031,  0.108,  0.013,  0.006, -0.152, -0.018,  0.117, -0.102,
#         0.029,  0.004, -0.21 ,  0.143,  0.011, -0.187,  0.055, -0.334,
#        -0.103,  0.175,  0.031, -0.17 ,  0.092,  0.072, -0.03 ,  0.045,
#         0.049, -0.133, -0.007, -0.037,  0.042,  0.098,  0.128,  0.096,
#        -0.117, -0.004,  0.309,  0.082, -0.003, -0.034, -0.196, -0.002,
#        -0.192,  0.046,  0.036,  0.013,  0.035, -0.214,  0.125,  0.121,
#        -0.263,  0.063])

# %%
china_synth_lr = (data.query("~china")
                  .pivot(index='year', columns="region")["fertrate"]
                  .values.dot(weights_lr))

# %%
plt.figure(figsize=(10,6))
plt.plot(data.query("china")["year"], data.query("china")["fertrate"], label="China")
plt.plot(data.query("china")["year"], china_synth_lr, label="Synthetic Control")
plt.vlines(x=1973, ymin=10, ymax=0, linestyle=":", lw=2, label="One Child Policy")
plt.ylabel("Fertility Rate")
plt.legend();
plt.savefig("rough_prediction.pdf")

# %%
from typing import List
from operator import add
from toolz import reduce, partial

def loss_w(W, X, y) -> float:
    return np.sqrt(np.mean((y - X.dot(W))**2))

# %%
from scipy.optimize import fmin_slsqp

def get_w(X, y):
    
    w_start = [1/X.shape[1]]*X.shape[1]

    weights = fmin_slsqp(partial(loss_w, X=X, y=y),
                         np.array(w_start),
                         f_eqcons=lambda x: np.sum(x) - 0.78,
                         bounds=[(0.0, 1.0)]*len(w_start),
                         disp=False)
    return weights

# %%
china_weights = get_w(X, y)
print("Sum:", china_weights.sum())
np.round(china_weights, 15)
# Out:
# Sum: 0.7800651113223329
# array([8.59451931e-07, 9.21850000e-11, 6.68750000e-11, 7.86090000e-11,
#        7.67500000e-11, 2.36819983e-02, 3.68420000e-11, 1.02409000e-10,
#        5.61110000e-11, 3.90000000e-13, 1.05300000e-11, 4.59660000e-11,
#        5.32596875e-02, 2.25737000e-10, 7.09710000e-11, 1.11898000e-10,
#        8.49480000e-11, 4.43522810e-06, 8.12190000e-11, 4.81800000e-11,
#        8.45350000e-11, 5.59588724e-03, 5.13223603e-07, 7.46950000e-11,
#        1.06080000e-10, 8.26200000e-11, 2.11929080e-06, 1.11812000e-10,
#        2.79250000e-11, 6.19580000e-11, 4.18570000e-11, 2.25430000e-11,
#        5.34230000e-11, 9.58900000e-12, 1.18586000e-10, 7.05290000e-11,
#        5.93910000e-11, 9.68600000e-12, 3.48550000e-11, 6.90382071e-02,
#        9.98620000e-11, 8.07482516e-07, 7.10633953e-07, 4.05100000e-12,
#        2.01455571e-06, 3.78680000e-11, 1.13599000e-10, 9.90360000e-11,
#        8.53930000e-11, 1.17153000e-10, 8.26010000e-11, 1.17442000e-10,
#        8.90242520e-07, 8.49632731e-07, 3.64700000e-11, 7.60690000e-11,
#        7.85210000e-11, 1.27159000e-10, 4.88470000e-11, 5.54330000e-11,
#        2.26035672e-07, 7.54900000e-12, 5.23970000e-11, 1.10156000e-10,
#        2.59984476e-07, 1.26230000e-11, 6.98520000e-11, 1.35450000e-11,
#        1.27155000e-10, 4.06450000e-11, 8.80080000e-11, 9.27540000e-11,
#        6.58440000e-11, 5.95550000e-11, 1.02167000e-10, 5.20220000e-11,
#        6.71380000e-11, 9.42570000e-11, 2.47700000e-11, 1.00135000e-10,
#        5.48560000e-11, 1.05650000e-11, 1.10799528e-01, 7.12030000e-11,
#        2.39955769e-07, 1.78965241e-05, 8.46230000e-11, 2.42906474e-02,
#        7.95499877e-03, 8.11215610e-08, 2.81499058e-06, 1.18942000e-10,
#        5.76270000e-11, 7.43030000e-11, 9.25482879e-07, 8.78540000e-11,
#        1.02556609e-03, 1.50414459e-02, 1.38893280e-08, 5.47070000e-11,
#        2.39510000e-11, 1.21936000e-10, 7.97750000e-11, 1.11425000e-10,
#        8.68870000e-11, 7.52880000e-11, 1.41590000e-11, 4.38330000e-11,
#        6.67900000e-12, 1.14509000e-10, 1.27184000e-10, 4.85554759e-02,
#        6.04840000e-11, 8.29960000e-11, 4.81570000e-11, 7.37760000e-11,
#        7.37910000e-11, 6.42830000e-11, 4.21093284e-07, 5.85600000e-11,
#        2.42816072e-03, 1.27172000e-10, 1.08638000e-10, 4.75830000e-11,
#        1.24730000e-11, 5.46540000e-11, 7.01310000e-11, 9.81196348e-03,
#        8.67310000e-11, 1.95060000e-11, 2.75617105e-06, 1.63104550e-01,
#        5.09670000e-11, 9.36880000e-11, 6.89260000e-11, 1.91810000e-11,
#        4.63400000e-11, 5.70675167e-07, 4.80064707e-07, 9.45800000e-12,
#        3.50660264e-07, 5.64910000e-11, 9.63210000e-11, 8.97140000e-11,
#        1.05785000e-10, 1.66873000e-10, 7.99700000e-12, 1.27158000e-10,
#        1.22968000e-10, 3.54650000e-11, 5.51230000e-11, 1.85534959e-06,
#        1.19087000e-10, 1.88317687e-06, 8.25153580e-06, 1.43830000e-11,
#        1.18303000e-10, 4.95040000e-11, 1.14301000e-10, 7.69840000e-11,
#        1.00848000e-10, 1.04378000e-10, 1.60273000e-10, 2.13780000e-11,
#        3.43702844e-07, 7.00210000e-11, 3.54090000e-11, 1.83796092e-01,
#        4.39020000e-11, 1.47939438e-06, 6.50700000e-12, 6.44490000e-11,
#        5.35726603e-06, 1.03589000e-10, 8.39520328e-07, 4.59598203e-06,
#        9.94690000e-11, 5.29150000e-11, 1.57420000e-11, 1.07292000e-10,
#        8.54460000e-11, 1.57690000e-11, 4.76786964e-02, 1.39313197e-02,
#        6.03485326e-06, 8.40960000e-11])

# %%
china_synth = data.query("~china").pivot(index='year', columns="region")["fertrate"].values.dot(china_weights)

# %%
plt.figure(figsize=(10,6))
plt.plot(data.query("china")["year"], data.query("china")["fertrate"], label="China")
plt.plot(data.query("china")["year"], china_synth, label="Synthetic Control")
plt.vlines(x=1973, ymin=10, ymax=2, linestyle=":", lw=2, label="One Child Policy")
plt.ylabel("Fertility Rate")
plt.legend();
plt.savefig("accurate_prediction.pdf")

# %%
plt.figure(figsize=(10,6))
plt.plot(data.query("china")["year"], data.query("china")["fertrate"] - china_synth,
         label="One Child Policy Effect")
plt.vlines(x=1973, ymin=-10, ymax=5, linestyle=":", lw=2, label="One Child Policy")
plt.hlines(y=0, xmin=1970, xmax=2000, lw=2)
plt.title("World - Synthetic Across Time")
plt.ylabel("Fertility Rate")
plt.legend();
plt.savefig("gap.pdf")

# %%
def synthetic_control(region: int, pool: List[int], data: pd.DataFrame) -> np.array:
    
    features = ["fertrate", "LifeExpB", "MtoF04", "Yschooling", "ChildBearing", "GDPpc"]
    
    inverted = (data.query("~after_treatment")
                .pivot(index='region', columns="year")[features]
                .T)
    
    y = inverted[region].values # treated
    X = inverted.drop(columns=region).values # donor pool

    weights = get_w(X, y)
    synthetic = (data.query(f"~(region=={region})")
                 .pivot(index='year', columns="region")["fertrate"]
                 .values.dot(weights))

    return (data
            .query(f"region=={region}")[["region", "year", "fertrate", "after_treatment"]]
            .assign(synthetic=synthetic))

# %%
control_pool = data["region"].unique()

synthetic_control(4, control_pool, data).head()
# Out:
#    region  year  fertrate  after_treatment  synthetic
# 0       4  1950      7.45            False   5.360065
# 1       4  1951      7.45            False   5.371378
# 2       4  1952      7.45            False   5.382691
# 3       4  1953      7.45            False   5.394004
# 4       4  1954      7.45            False   5.405317

# %%
from joblib import Parallel, delayed

parallel_fn = delayed(partial(synthetic_control, pool=control_pool, data=data))

sinthetic_countries = Parallel(n_jobs=8)(parallel_fn(state) for state in control_pool)

# %%
sinthetic_countries[0].head()
# Out:
#    region  year  fertrate  after_treatment  synthetic
# 0       4  1950      7.45            False   5.360065
# 1       4  1951      7.45            False   5.371378
# 2       4  1952      7.45            False   5.382691
# 3       4  1953      7.45            False   5.394004
# 4       4  1954      7.45            False   5.405317

# %%
def pre_treatment_error(region):
    pre_treat_error = (region.query("~after_treatment")["fertrate"] 
                       - region.query("~after_treatment")["synthetic"]) ** 2
    return pre_treat_error.mean()

plt.figure(figsize=(12,7))
for region in sinthetic_countries:
    
    # remove units with mean error above 80.
    if pre_treatment_error(region) < 80:
        plt.plot(region["year"], region["fertrate"] - region["synthetic"], color="C5",alpha=0.4)

plt.plot(data.query("china")["year"], data.query("china")["fertrate"] - china_synth,
        label="China");

plt.vlines(x=1973, ymin=-5, ymax=10, linestyle=":", lw=2, label="One Child Policy")
plt.hlines(y=0, xmin=1970, xmax=2000, lw=3)
plt.ylabel("Fertlity")
plt.title("Distribution of Effects")
plt.title("Countries - Synthetic Across Time (Large Pre-Treatment Errors Removed)")
plt.legend();
plt.savefig("distribution.pdf")

# %%
china_number = 3

effects = [region.query("year==2000").iloc[0]["fertrate"] - region.query("year==2000").iloc[0]["synthetic"]
           for region in sinthetic_countries
           if pre_treatment_error(region) < 80] # filter out noise

china_effect = data.query("china & year==2000").iloc[0]["fertrate"] - china_synth[-1] 

print("China Treatment Effect for the Year 2000:", china_effect)
np.array(effects)
# Out:
# China Treatment Effect for the Year 2000: -1.3207688172043035
# array([ 4.25823656, -1.10645161, -0.75054839,  3.66405914, -0.9496129 ,
#        -0.7032957 , -1.58098925, -1.39398925, -1.51262366, -1.91075269,
#        -1.26731183, -1.19593011, -0.49819892, -0.09202688, -1.52468817,
#        -1.95398387, -1.59908602,  0.34129032,  2.72905914,  0.34531183,
#         0.79873656, -1.85746774,  0.15328495, -0.90135484, -0.9878172 ,
#        -2.01129032,  3.34937634,  3.81687634,  0.40764516,  0.54739247,
#         2.37315591, -1.78005376,  2.19721505,  4.11547312, -1.19391935,
#        -1.82328495, -0.87622043,  2.13488172,  3.81285484,  1.85840323,
#        -0.89230645,  2.61444624, -1.8805914 , -1.62723656, -1.14566129,
#        -1.55484946, -2.12188172, -1.49854839,  1.21797849, -0.37051613,
#        -0.23479032, -0.0276828 , -0.36448387,  2.52597312,  2.07858065,
#        -1.91075269,  3.28603763, -0.17145161, -1.53876344, -1.37790323,
#        -0.80182258,  1.28533871,  2.67074731, -1.66041398, -1.89064516,
#         1.41704301, -2.02134409,  1.17977419,  2.83663441,  2.57121505,
#        -0.2398172 ,  1.04706452,  0.73640323, -2.2375    , -1.95096774,
#        -1.18688172,  0.05073656, -0.78171505, -1.05517742,  1.63621505,
#        -1.37790323, -0.3122043 , -2.01129032, -0.68720968, -1.91175806,
#         0.79974194, -1.4683871 ,  1.76088172,  0.80175269, -1.27636022,
#        -1.80317742, -0.41575806, -0.86516129,  1.04907527, -2.02134409,
#        -1.04110215,  0.83291935,  2.63354839, -0.33130645, -1.8805914 ,
#        -1.54751022, -2.33401613, -1.54580108,  2.29976344,  3.00553763,
#        -0.43787634, -0.31723118,  3.65601613, -1.56892473,  2.15398387,
#        -1.27736559, -0.5162957 ,  1.04505376, -1.83534946, -1.12354301,
#        -1.39298387, -0.57259677,  2.5692043 , -0.35945699,  0.76153763,
#         0.77360215, -1.5488172 , -0.67413978, -1.28741935, -0.17848925,
#         4.50153763,  2.86076344, -1.41811828,  0.46093011,  1.32655914,
#        -0.55852151,  1.27126344,  0.29403763, -0.3333172 ,  0.55644086,
#        -1.90069892, -1.71973118, -0.02064516, -1.96102151, -2.07663978,
#         2.39225806,  1.24914516,  2.02831183,  0.71931183,  2.30378495,
#        -1.43701935, -1.08835484,  3.01257527, -1.66946237, -1.97107527,
#        -2.01129032,  1.46731183,  4.37284946, -0.39665591, -2.05150538,
#        -1.02501613, -0.95262903, -0.88627419,  2.1952043 , -0.45295699,
#         0.95356452, -1.72978495, -1.77      ,  0.70121505,  0.71227419,
#         2.44152151, -1.59808065,  3.87217204,  2.16102151,  0.99478495,
#        -1.51563978, -1.12454839, -0.78573656, -0.42581183,  3.62384409,
#        -2.16209677, -0.61984946, -1.62924731, -1.21101075, -1.02401075,
#        -0.68419355,  1.11341935, -0.44089247, -1.25725806,  2.85171505,
#         0.80879032, -1.60159946])

# %%
np.mean(np.array(effects) < china_effect)
# Out:
# 0.29411764705882354

# %%
_, bins, _ = plt.hist(effects, bins=20, color="C5", alpha=0.5);
plt.hist([china_effect], bins=bins, color="C0", label="China")
plt.ylabel("Frequency")
plt.title("Distribution of Effects")
plt.legend();
plt.savefig("impact_distribution.pdf")
